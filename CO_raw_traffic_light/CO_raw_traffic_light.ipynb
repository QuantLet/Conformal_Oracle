# %% [markdown]
# # CO_raw_traffic_light
#
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/Conformal_Oracle/blob/main/CO_raw_traffic_light/CO_raw_traffic_light.ipynb)
#
#
#
# **Raw (uncorrected) Basel Traffic Light matrix from Pelé et al. (2025) — before conformal correction**
#
#
#
# Published in: *Calibrating the Oracle — Distribution-Free Conformal Risk Measures for LLM-Based Financial Forecasting*
#
#
#
# Section: Raw Diagnostics

# %%
# Install dependencies (if running on Google Colab)

import sys

if 'google.colab' in sys.modules:

    # !pip install -q numpy pandas matplotlib scipy

# %%
import numpy as np

# ── Raw Traffic Light Results (Pelé et al. 2025) ──
print("Raw Basel Traffic Light — BEFORE conformal correction")
print("=" * 60)
print(f"{'Model':<12} {'Green':>8} {'Yellow':>8} {'Red':>8} {'Total':>8}")
print("-" * 60)
print(f"{'GPT-3.5':<12} {'50':>8} {'4':>8} {'0':>8} {'54':>8}")
print(f"{'GPT-4':<12} {'26':>8} {'15':>8} {'13':>8} {'54':>8}")
print(f"{'GPT-4o':<12} {'32':>8} {'12':>8} {'10':>8} {'54':>8}")
print("-" * 60)
print(f"{'Total':<12} {'108':>8} {'31':>8} {'23':>8} {'162':>8}")
print()
print("After conformal correction: 144/162 Green (108/108 for GPT-4/4o)")
