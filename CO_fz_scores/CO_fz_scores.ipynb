# %% [markdown]
# # CO_fz_scores
#
# Fissler–Ziegel FZ₀ joint VaR–ES scores (Table 13).
#
# Raw ES via Gaussian tail-mean; conformal ES correction via median shift (Appendix C).
#
# **Output:** `tab_fz_scores.tex`, `tab_fz_scores.csv`
# **Paper:** Pele, Bolovaneanu, Ginavar, Lessmann, Härdle (2026)
# **Q** [Conformal_Oracle](https://github.com/QuantLet/Conformal_Oracle/)

# %%
# %run run_fz_scores.py
