# %% [markdown]
# # CO — Sharpness penalty
#
# Calibration-efficiency trade-off diagnostic.
#
# The frontier figure produced by `CO_frontier` (and the expanded 9-model version generated for Appendix I) visualises the sharpness penalty: conformal correction moves forecasts toward the 99% coverage target at the cost of wider VaR intervals. See `CFP_Calibration_Efficiency_Frontier` for the two-panel version.
