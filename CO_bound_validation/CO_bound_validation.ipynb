# %% [markdown]
# # CO_bound_validation
#
# Empirical evaluation of the coverage bound from Theorem 3.5 on six
# representative (model, asset) pairs spanning a range of dependence structures.
#
# **Output:** `tab_bound_validation.tex`
# **Paper:** Pele, Bolovaneanu, Ginavar, Lessmann, Härdle (2026)
# **Q** [Conformal_Oracle](https://github.com/QuantLet/Conformal_Oracle/)

# %%
# %run run_bound_validation.py
