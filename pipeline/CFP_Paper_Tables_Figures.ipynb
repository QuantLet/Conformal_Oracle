# %% [markdown]
# # CFP_Paper_Tables_Figures
#
# Collects all paper outputs.

# %%
import shutil
from pathlib import Path

SRC_TAB = Path('../cfp_ijf_data/paper_outputs/tables')
SRC_FIG = Path('../cfp_ijf_data/paper_outputs/figures')
OUT = Path('results')
OUT.mkdir(exist_ok=True)

# Copy tables
for f in sorted(SRC_TAB.glob('*.tex')):
    shutil.copy(f, OUT / f.name)
    print(f'Table: {f.name}')

# Copy figures
for f in sorted(SRC_FIG.glob('*.pdf')):
    shutil.copy(f, OUT / f.name)
    print(f'Figure: {f.name}')

print(f'\nTotal: {len(list(OUT.glob("*.tex")))} tables, {len(list(OUT.glob("*.pdf")))} figures')
# Out:
# Table: cross_sectional.tex
# Table: detection_lag.tex
# Table: dm_tests.tex
# Table: master_table.tex
# Table: multi_quantile.tex
# Table: panel_pooled.tex
# Table: practitioner_guide.tex
# Table: qv_ranking.tex
# Table: rolling_vs_static.tex
# Table: tab_baselines.tex
# Table: tab_baselines_by_model.tex
# Table: tab_simulation_extended.tex
# Figure: capital_charge_cumulative.pdf
# Figure: fig_coverage_frontier.pdf
# Figure: fig_covid_response.pdf
# Figure: fig_detection_lag.pdf
# Figure: fig_dm_heatmap.pdf
# Figure: fig_frontier_killer.pdf
# Figure: fig_qV_ranking.pdf
# Figure: fig_qv_scatter.pdf
# Figure: fig_rolling_qv.pdf
# Figure: fig_simulation_qV_distribution.pdf
# Figure: fig_traffic_light.pdf
# Figure: fig_violation_rates.pdf
#
# Total: 12 tables, 12 figures
