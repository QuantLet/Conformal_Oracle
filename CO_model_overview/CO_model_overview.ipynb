# %% [markdown]
# # CO_model_overview
#
# Model overview table (Table 2): 5 TSFMs + 4 classical benchmarks.
#
# **Output:** `tab_models.tex`
# **Paper:** Pele, Bolovaneanu, Ginavar, Lessmann, Härdle (2026)
# **Q** [Conformal_Oracle](https://github.com/QuantLet/Conformal_Oracle/)

# %%
# %run run_model_overview.py
