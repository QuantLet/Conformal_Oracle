# %% [markdown]
# # CO_asset_overview
#
# Asset universe table (Table 1): 24 assets across 5 classes.
#
# **Output:** `tab_assets.tex`
# **Paper:** Pele, Bolovaneanu, Ginavar, Lessmann, Härdle (2026)
# **Q** [Conformal_Oracle](https://github.com/QuantLet/Conformal_Oracle/)

# %%
# %run run_asset_overview.py
