# %% [markdown]
# # CO_cross_architecture
#
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/Conformal_Oracle/blob/main/CO_cross_architecture/CO_cross_architecture.ipynb)
#
#
#
# **Cross-architecture comparison: GPT-3.5, GPT-4, GPT-4o conformal calibration performance**
#
#
#
# Published in: *Calibrating the Oracle — Distribution-Free Conformal Risk Measures for LLM-Based Financial Forecasting*
#
#
#
# Section: Architecture Comparison

# %%
# Install dependencies (if running on Google Colab)

import sys

if 'google.colab' in sys.modules:

    # !pip install -q numpy pandas matplotlib scipy

# %%
import numpy as np
import pandas as pd

# ── Cross-Architecture Comparison ──
results = pd.DataFrame({
    'Model': ['GPT-3.5', 'GPT-4', 'GPT-4o'],
    'Mean q̂_V': [0.002, 0.024, 0.020],
    'Mean q̂_E': [0.001, 0.021, 0.009],
    'Green/9': ['8/9', '9/9', '9/9'],
    'Z₂ Pass/9': ['9/9', '9/9', '9/9'],
    'Mean VaR': [0.020, 0.044, 0.038],
    'Interpretation': [
        'Already conservative (near-zero correction)',
        'Largest correction needed (under-covers)',
        'Moderate correction (best efficiency)',
    ],
})

print("Cross-Architecture Summary (w=30, 9 assets)")
print("=" * 80)
print(results.to_string(index=False))
print()
print("GPT-3.5: Overly conservative → minimal conformal correction needed")
print("GPT-4:   Under-covers most → largest q̂_V, but best raw distributional fit")
print("GPT-4o:  Best balance of coverage and efficiency after correction")
