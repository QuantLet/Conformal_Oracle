# %% [markdown]
# # CO — Quantile Score diagnostics
#
# This Quantlet reports Quantile Score (pinball loss) diagnostics.
#
# The output table `tab_quantile_scores.tex` is produced by the `CO_full_evaluation` pipeline and is reproduced here for convenience.
