# %% [markdown]
# # CO_quantile_scores
#
# Diebold–Mariano test p-values for pairwise Quantile Score comparisons (Table 8).
#
# Driscoll–Kraay panel HAC (Bartlett kernel, Andrews 1991 bandwidth), HLN small-sample correction.
#
# **Output:** `tab_dm_pvalues.tex`, `tab_dm_pvalues.csv`
# **Paper:** Pele, Bolovaneanu, Ginavar, Lessmann, Härdle (2026)
# **Q** [Conformal_Oracle](https://github.com/QuantLet/Conformal_Oracle/)

# %%
# %run run_dm_pvalues.py
