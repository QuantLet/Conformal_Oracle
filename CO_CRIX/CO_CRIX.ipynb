# %% [markdown]
# # CO_CRIX
#
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/Conformal_Oracle/blob/main/CO_CRIX/CO_CRIX.ipynb)
#
#
#
# **GPT-4 CRIX cryptocurrency VaR and ES time series with conformal correction bands**
#
#
#
# Published in: *Calibrating the Oracle — Distribution-Free Conformal Risk Measures for LLM-Based Financial Forecasting*
#
#
#
# Section: Asset Case Study: CRIX

# %%
# Install dependencies (if running on Google Colab)

import sys

if 'google.colab' in sys.modules:

    # !pip install -q numpy pandas matplotlib scipy

# %%
import numpy as np
import matplotlib.pyplot as plt

# ── CRIX Case Study ──
print("CRIX (CRyptocurrency IndeX) — GPT-4, w=30")
print("=" * 50)
print("Key statistics:")
print("  Raw π̂ = 0.0862  (Red zone)")
print("  q̂_V = 0.0263")
print("  Corrected π̂ = 0.0058  (Green zone)")
print("  Z₂ = -0.25  (ES adequate)")
print()
print("CRIX has the highest volatility among the 9 assets,")
print("yet conformal correction successfully achieves Green zone.")
print()
print("Load CRIX data and run DualConformalCalibrator to reproduce.")
