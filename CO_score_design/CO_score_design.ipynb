# %% [markdown]
# # CO_score_design
#
#
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/QuantLet/Conformal_Oracle/blob/main/CO_score_design/CO_score_design.ipynb)
#
#
#
# **Score design practical impact: capital savings from one-sided vs two-sided conformal scores**
#
#
#
# Published in: *Calibrating the Oracle — Distribution-Free Conformal Risk Measures for LLM-Based Financial Forecasting*
#
#
#
# Section: Score Design Impact

# %%
# Install dependencies (if running on Google Colab)

import sys

if 'google.colab' in sys.modules:

    # !pip install -q numpy pandas matplotlib scipy

# %%
import numpy as np

# ── Score Design: Capital Impact ──
print("Score Design: One-Sided vs Two-Sided")
print("=" * 55)
print()
print("Definition 3.2 (One-sided):  s_t^V = q_lo(t) - r(t)")
print("CQR (Two-sided):  s_t^V = max(q_lo(t) - r(t), r(t) - q_hi(t))")
print()
print("Impact on capital requirements:")
print("-" * 55)
print(f"{'Metric':<30} {'One-sided':>12} {'Two-sided':>12}")
print("-" * 55)
print(f"{'Mean q̂_V (GPT-4):':<30} {'0.024':>12} {'0.041':>12}")
print(f"{'VaR increase:':<30} {'53%':>12} {'91%':>12}")
print(f"{'Capital waste:':<30} {'Minimal':>12} {'Significant':>12}")
print(f"{'Coverage guarantee:':<30} {'Yes':>12} {'Yes':>12}")
print("-" * 55)
print()
print("Key insight: Two-sided scores capture upper-tail exceedances")
print("that are irrelevant for VaR (a lower-tail risk measure),")
print("inflating q̂_V by ~70% and wasting capital.")
