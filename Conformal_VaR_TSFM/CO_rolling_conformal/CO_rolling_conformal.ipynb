# %% [markdown]
# # CO — Rolling conformal correction
#
# Rolling conformal correction with 250-day window. Produces the static-vs-rolling comparison (Table 9 in the paper) and per-asset rolling qV series. Source notebook: `../CO_full_evaluation/CFP_Conformal_Calibration.ipynb`.
