# %% [markdown]
# # CO — Baseline comparison (aggregated)
#
# Aggregated baseline comparison: conformal vs scale correction, historical quantile, QR on residuals, ACI, and isotonic regression. See `Conformal_VaR_TSFM/CO_full_evaluation` for the source pipeline; results in `results/` subfolder.
